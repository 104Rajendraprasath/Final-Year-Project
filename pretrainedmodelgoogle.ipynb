# %%
import cv2
import os
import shutil

# --- Configuration for Frame Extraction ---
# ==============================================================================
# IMPORTANT: SET YOUR PATHS HERE!
# 1. The path to your dataset containing the 'Violence' and 'NonViolence' video folders.
VIDEO_DATASET_PATH = r"/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Dataset/train"
# 2. The path to the NEW, EMPTY folder where the extracted frames will be saved.
FRAME_OUTPUT_PATH = r"/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames/train"
# ==============================================================================

# Define the names of your class folders
CLASSES = ["Violence", "NonViolence"]

# It's good practice to start with a clean slate
if os.path.exists(FRAME_OUTPUT_PATH):
    shutil.rmtree(FRAME_OUTPUT_PATH)
    print(f"Removed existing frames directory: {FRAME_OUTPUT_PATH}")

os.makedirs(FRAME_OUTPUT_PATH, exist_ok=True)
print(f"Created main frames directory: {FRAME_OUTPUT_PATH}")

# Loop through each class (e.g., 'Violence', then 'NonViolence')
for category in CLASSES:
    video_class_path = os.path.join(VIDEO_DATASET_PATH, category)
    frame_class_path = os.path.join(FRAME_OUTPUT_PATH, category)

    # Create the output subfolder (e.g., .../Extracted_Frames/Violence)
    os.makedirs(frame_class_path, exist_ok=True)
    
    # Check if the source video directory exists
    if not os.path.exists(video_class_path):
        print(f"[WARNING] Source directory not found: {video_class_path}. Skipping.")
        continue

    # Loop through every video file in the source directory
    for video_name in os.listdir(video_class_path):
        video_path = os.path.join(video_class_path, video_name)

        # Ensure we are processing a video file
        if not video_path.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
            continue

        print(f"[INFO] Processing video: {video_name}...")
        
        cap = cv2.VideoCapture(video_path)
        frame_count = 0
        
        while True:
            # Read one frame from the video stream
            success, frame = cap.read()
            
            # If 'success' is False, we have reached the end of the video
            if not success:
                break
            
            # Construct the output filename
            # Example: Violence/V_7_frame_0.jpg
            base_video_name = os.path.splitext(video_name)[0]
            output_filename = f"{base_video_name}_frame_{frame_count}.jpg"
            output_filepath = os.path.join(frame_class_path, output_filename)
            
            # Save the current frame as a JPG image
            cv2.imwrite(output_filepath, frame)
            
            frame_count += 1
            
        cap.release()
        print(f"  -> Extracted {frame_count} frames.")

print("\n[SUCCESS] All videos have been processed and frames have been extracted.")
# Out:
# Removed existing frames directory: /media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames/train
# Created main frames directory: /media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames/train
# [INFO] Processing video: V_1.mp4...
#   -> Extracted 103 frames.
# [INFO] Processing video: V_10.mp4...
#   -> Extracted 96 frames.
# [INFO] Processing video: V_100.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_101.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_102.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_103.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_104.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_105.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_106.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_107.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_108.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_109.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_11.mp4...
#   -> Extracted 222 frames.
# [INFO] Processing video: V_110.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_111.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_112.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_113.mp4...
#   -> Extracted 162 frames.
# [INFO] Processing video: V_114.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_115.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_116.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_117.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_118.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_119.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_12.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_121.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_122.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_123.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_124.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_125.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_126.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_127.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_128.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_129.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_13.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_130.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_131.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_132.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_133.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_134.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_135.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_136.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_137.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_138.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_139.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_14.mp4...
#   -> Extracted 180 frames.
# [INFO] Processing video: V_141.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_142.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_143.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_144.mp4...
#   -> Extracted 213 frames.
# [INFO] Processing video: V_145.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_146.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_147.mp4...
#   -> Extracted 180 frames.
# [INFO] Processing video: V_148.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_149.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_15.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_150.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_151.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_152.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_153.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_154.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_155.mp4...
#   -> Extracted 177 frames.
# [INFO] Processing video: V_156.mp4...
#   -> Extracted 98 frames.
# [INFO] Processing video: V_157.mp4...
#   -> Extracted 90 frames.
# [INFO] Processing video: V_158.mp4...
#   -> Extracted 94 frames.
# [INFO] Processing video: V_159.mp4...
#   -> Extracted 76 frames.
# [INFO] Processing video: V_16.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: V_161.mp4...
#   -> Extracted 102 frames.
# [INFO] Processing video: V_162.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_163.mp4...
#   -> Extracted 98 frames.
# [INFO] Processing video: V_164.mp4...
#   -> Extracted 106 frames.
# [INFO] Processing video: V_165.mp4...
#   -> Extracted 100 frames.
# [INFO] Processing video: V_166.mp4...
#   -> Extracted 124 frames.
# [INFO] Processing video: V_167.mp4...
#   -> Extracted 84 frames.
# [INFO] Processing video: V_168.mp4...
#   -> Extracted 88 frames.
# [INFO] Processing video: V_169.mp4...
#   -> Extracted 98 frames.
# [INFO] Processing video: V_17.mp4...
#   -> Extracted 192 frames.
# [INFO] Processing video: V_170.mp4...
#   -> Extracted 110 frames.
# [INFO] Processing video: V_171.mp4...
#   -> Extracted 62 frames.
# [INFO] Processing video: V_172.mp4...
#   -> Extracted 74 frames.
# [INFO] Processing video: V_173.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_174.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_175.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: V_176.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_177.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_178.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_179.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_18.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_181.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_182.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_183.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_184.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_185.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_186.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_187.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_188.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_189.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_19.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_190.mp4...
#   -> Extracted 186 frames.
# [INFO] Processing video: V_191.mp4...
#   -> Extracted 165 frames.
# [INFO] Processing video: V_192.mp4...
#   -> Extracted 117 frames.
# [INFO] Processing video: V_193.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_194.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_195.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_196.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_197.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_198.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_120.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_140.mp4...
#   -> Extracted 180 frames.
# [INFO] Processing video: V_160.mp4...
#   -> Extracted 106 frames.
# [INFO] Processing video: V_180.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_199.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_22.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_24.mp4...
#   -> Extracted 210 frames.
# [INFO] Processing video: V_26.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_28.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_31.mp4...
#   -> Extracted 62 frames.
# [INFO] Processing video: V_33.mp4...
#   -> Extracted 143 frames.
# [INFO] Processing video: V_36.mp4...
#   -> Extracted 140 frames.
# [INFO] Processing video: V_38.mp4...
#   -> Extracted 143 frames.
# [INFO] Processing video: V_4.mp4...
#   -> Extracted 151 frames.
# [INFO] Processing video: V_54.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_72.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_2.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: V_20.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_21.mp4...
#   -> Extracted 180 frames.
# [INFO] Processing video: V_37.mp4...
#   -> Extracted 143 frames.
# [INFO] Processing video: V_55.mp4...
#   -> Extracted 156 frames.
# [INFO] Processing video: V_56.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_57.mp4...
#   -> Extracted 90 frames.
# [INFO] Processing video: V_58.mp4...
#   -> Extracted 117 frames.
# [INFO] Processing video: V_59.mp4...
#   -> Extracted 162 frames.
# [INFO] Processing video: V_6.mp4...
#   -> Extracted 142 frames.
# [INFO] Processing video: V_60.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: V_61.mp4...
#   -> Extracted 114 frames.
# [INFO] Processing video: V_62.mp4...
#   -> Extracted 114 frames.
# [INFO] Processing video: V_63.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_64.mp4...
#   -> Extracted 117 frames.
# [INFO] Processing video: V_65.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: V_66.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: V_67.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_68.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: V_69.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: V_7.mp4...
#   -> Extracted 70 frames.
# [INFO] Processing video: V_70.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_71.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_73.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_74.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_75.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_76.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_77.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_78.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_79.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_8.mp4...
#   -> Extracted 85 frames.
# [INFO] Processing video: V_80.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_81.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_82.mp4...
#   -> Extracted 162 frames.
# [INFO] Processing video: V_83.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_84.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_85.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_86.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_87.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_88.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_89.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_9.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_90.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_91.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_92.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_93.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_94.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_95.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_96.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_97.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_98.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_99.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_23.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_25.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_27.mp4...
#   -> Extracted 168 frames.
# [INFO] Processing video: V_29.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_3.mp4...
#   -> Extracted 174 frames.
# [INFO] Processing video: V_30.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: V_32.mp4...
#   -> Extracted 140 frames.
# [INFO] Processing video: V_34.mp4...
#   -> Extracted 143 frames.
# [INFO] Processing video: V_35.mp4...
#   -> Extracted 140 frames.
# [INFO] Processing video: V_39.mp4...
#   -> Extracted 140 frames.
# [INFO] Processing video: V_40.mp4...
#   -> Extracted 140 frames.
# [INFO] Processing video: V_41.mp4...
#   -> Extracted 170 frames.
# [INFO] Processing video: V_42.mp4...
#   -> Extracted 143 frames.
# [INFO] Processing video: V_43.mp4...
#   -> Extracted 143 frames.
# [INFO] Processing video: V_44.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_45.mp4...
#   -> Extracted 99 frames.
# [INFO] Processing video: V_46.mp4...
#   -> Extracted 90 frames.
# [INFO] Processing video: V_47.mp4...
#   -> Extracted 102 frames.
# [INFO] Processing video: V_48.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_49.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_5.mp4...
#   -> Extracted 114 frames.
# [INFO] Processing video: V_50.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_51.mp4...
#   -> Extracted 174 frames.
# [INFO] Processing video: V_52.mp4...
#   -> Extracted 210 frames.
# [INFO] Processing video: V_53.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: NV_1.mp4...
#   -> Extracted 66 frames.
# [INFO] Processing video: NV_10.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_100.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_101.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_102.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_103.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_104.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_105.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_106.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_107.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_108.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_109.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_11.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: NV_110.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_111.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_112.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_113.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_114.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_115.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_116.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_117.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_118.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_119.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_12.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: NV_121.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_122.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_123.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_124.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_125.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_126.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_127.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_128.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_129.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_13.mp4...
#   -> Extracted 155 frames.
# [INFO] Processing video: NV_130.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_131.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_132.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_133.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_134.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_135.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_136.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_137.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: NV_138.mp4...
#   -> Extracted 98 frames.
# [INFO] Processing video: NV_139.mp4...
#   -> Extracted 113 frames.
# [INFO] Processing video: NV_14.mp4...
#   -> Extracted 110 frames.
# [INFO] Processing video: NV_141.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: NV_142.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_143.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_144.mp4...
#   -> Extracted 113 frames.
# [INFO] Processing video: NV_145.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_146.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_147.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_148.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_149.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_15.mp4...
#   -> Extracted 133 frames.
# [INFO] Processing video: NV_150.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_151.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_152.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_153.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_154.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_155.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_156.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_157.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_158.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_159.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_16.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_161.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_162.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_163.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_164.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_165.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_166.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_167.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_168.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_169.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_17.mp4...
#   -> Extracted 128 frames.
# [INFO] Processing video: NV_170.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_171.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_172.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_173.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_174.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_175.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_176.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_177.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_178.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_179.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_18.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: NV_181.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: NV_182.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_183.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_184.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_185.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_186.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_187.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_188.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_189.mp4...
#   -> Extracted 50 frames.
# [INFO] Processing video: NV_19.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: NV_190.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_191.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_192.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_193.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_194.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_195.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_196.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_197.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_198.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_120.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_140.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_160.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_180.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: NV_199.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_22.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: NV_24.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: NV_26.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: NV_28.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: NV_31.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_33.mp4...
#   -> Extracted 133 frames.
# [INFO] Processing video: NV_36.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: NV_38.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: NV_4.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_54.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_72.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_2.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_20.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_200.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_21.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: NV_37.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: NV_55.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_56.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_57.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_58.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_59.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_6.mp4...
#   -> Extracted 103 frames.
# [INFO] Processing video: NV_60.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_61.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_62.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_63.mp4...
#   -> Extracted 88 frames.
# [INFO] Processing video: NV_64.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_65.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_66.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_67.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_68.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_69.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_7.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_70.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_71.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_73.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_74.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_75.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_76.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_77.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_78.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_79.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_8.mp4...
#   -> Extracted 128 frames.
# [INFO] Processing video: NV_80.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_81.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_82.mp4...
#   -> Extracted 103 frames.
# [INFO] Processing video: NV_83.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_84.mp4...
#   -> Extracted 100 frames.
# [INFO] Processing video: NV_85.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_86.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: NV_87.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: NV_88.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: NV_89.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: NV_9.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_90.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: NV_91.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: NV_92.mp4...
#   -> Extracted 133 frames.
# [INFO] Processing video: NV_93.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: NV_94.mp4...
#   -> Extracted 100 frames.
# [INFO] Processing video: NV_95.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: NV_96.mp4...
#   -> Extracted 171 frames.
# [INFO] Processing video: NV_97.mp4...
#   -> Extracted 88 frames.
# [INFO] Processing video: NV_98.mp4...
#   -> Extracted 95 frames.
# [INFO] Processing video: NV_99.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: NV_23.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: NV_25.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: NV_27.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_29.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_3.mp4...
#   -> Extracted 128 frames.
# [INFO] Processing video: NV_30.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: NV_32.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: NV_34.mp4...
#   -> Extracted 133 frames.
# [INFO] Processing video: NV_35.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_39.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_40.mp4...
#   -> Extracted 133 frames.
# [INFO] Processing video: NV_41.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_42.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: NV_43.mp4...
#   -> Extracted 118 frames.
# [INFO] Processing video: NV_44.mp4...
#   -> Extracted 133 frames.
# [INFO] Processing video: NV_45.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: NV_46.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_47.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_48.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_49.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_5.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: NV_50.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_51.mp4...
#   -> Extracted 125 frames.
# [INFO] Processing video: NV_52.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: NV_53.mp4...
#   -> Extracted 150 frames.
#
# [SUCCESS] All videos have been processed and frames have been extracted.

# %%
import cv2
import os
import shutil

# --- Configuration for Frame Extraction ---
# ==============================================================================
# IMPORTANT: SET YOUR PATHS HERE!
# 1. The path to your dataset containing the 'Violence' and 'NonViolence' video folders.
VIDEO_DATASET_PATH = r"/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Dataset/test"
# 2. The path to the NEW, EMPTY folder where the extracted frames will be saved.
FRAME_OUTPUT_PATH = r"/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames/test"
# ==============================================================================

# Define the names of your class folders
CLASSES = ["Violence", "NonViolence"]

# It's good practice to start with a clean slate
if os.path.exists(FRAME_OUTPUT_PATH):
    shutil.rmtree(FRAME_OUTPUT_PATH)
    print(f"Removed existing frames directory: {FRAME_OUTPUT_PATH}")

os.makedirs(FRAME_OUTPUT_PATH, exist_ok=True)
print(f"Created main frames directory: {FRAME_OUTPUT_PATH}")

# Loop through each class (e.g., 'Violence', then 'NonViolence')
for category in CLASSES:
    video_class_path = os.path.join(VIDEO_DATASET_PATH, category)
    frame_class_path = os.path.join(FRAME_OUTPUT_PATH, category)

    # Create the output subfolder (e.g., .../Extracted_Frames/Violence)
    os.makedirs(frame_class_path, exist_ok=True)
    
    # Check if the source video directory exists
    if not os.path.exists(video_class_path):
        print(f"[WARNING] Source directory not found: {video_class_path}. Skipping.")
        continue

    # Loop through every video file in the source directory
    for video_name in os.listdir(video_class_path):
        video_path = os.path.join(video_class_path, video_name)

        # Ensure we are processing a video file
        if not video_path.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
            continue

        print(f"[INFO] Processing video: {video_name}...")
        
        cap = cv2.VideoCapture(video_path)
        frame_count = 0
        
        while True:
            # Read one frame from the video stream
            success, frame = cap.read()
            
            # If 'success' is False, we have reached the end of the video
            if not success:
                break
            
            # Construct the output filename
            # Example: Violence/V_7_frame_0.jpg
            base_video_name = os.path.splitext(video_name)[0]
            output_filename = f"{base_video_name}_frame_{frame_count}.jpg"
            output_filepath = os.path.join(frame_class_path, output_filename)
            
            # Save the current frame as a JPG image
            cv2.imwrite(output_filepath, frame)
            
            frame_count += 1
            
        cap.release()
        print(f"  -> Extracted {frame_count} frames.")

print("\n[SUCCESS] All videos have been processed and frames have been extracted.")
# Out:
# Removed existing frames directory: /media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames/test
# Created main frames directory: /media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames/test
# [INFO] Processing video: V_401.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_402.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_403.mp4...
#   -> Extracted 102 frames.
# [INFO] Processing video: V_404.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_405.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_406.mp4...
#   -> Extracted 114 frames.
# [INFO] Processing video: V_407.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_408.mp4...
#   -> Extracted 105 frames.
# [INFO] Processing video: V_409.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_451.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_452.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_453.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_454.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_455.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: V_456.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_457.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_458.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_459.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: V_460.mp4...
#   -> Extracted 156 frames.
# [INFO] Processing video: V_461.mp4...
#   -> Extracted 171 frames.
# [INFO] Processing video: V_462.mp4...
#   -> Extracted 186 frames.
# [INFO] Processing video: V_463.mp4...
#   -> Extracted 189 frames.
# [INFO] Processing video: V_464.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_465.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_466.mp4...
#   -> Extracted 165 frames.
# [INFO] Processing video: V_467.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_468.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_469.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_410.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_430.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_450.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_470.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_490.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_411.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_412.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_413.mp4...
#   -> Extracted 117 frames.
# [INFO] Processing video: V_414.mp4...
#   -> Extracted 114 frames.
# [INFO] Processing video: V_415.mp4...
#   -> Extracted 96 frames.
# [INFO] Processing video: V_416.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_417.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_418.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_419.mp4...
#   -> Extracted 102 frames.
# [INFO] Processing video: V_420.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: V_421.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_422.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_423.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_424.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_425.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_426.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_427.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_428.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_429.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_431.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_432.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_433.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: V_434.mp4...
#   -> Extracted 117 frames.
# [INFO] Processing video: V_435.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: V_436.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_437.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_438.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_439.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: V_440.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_441.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_442.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_443.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_444.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_445.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_446.mp4...
#   -> Extracted 114 frames.
# [INFO] Processing video: V_447.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_448.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_449.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_471.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_472.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_473.mp4...
#   -> Extracted 126 frames.
# [INFO] Processing video: V_474.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_475.mp4...
#   -> Extracted 141 frames.
# [INFO] Processing video: V_476.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_477.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_478.mp4...
#   -> Extracted 135 frames.
# [INFO] Processing video: V_479.mp4...
#   -> Extracted 159 frames.
# [INFO] Processing video: V_480.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_481.mp4...
#   -> Extracted 123 frames.
# [INFO] Processing video: V_482.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_483.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_484.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: V_485.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_486.mp4...
#   -> Extracted 150 frames.
# [INFO] Processing video: V_487.mp4...
#   -> Extracted 111 frames.
# [INFO] Processing video: V_488.mp4...
#   -> Extracted 171 frames.
# [INFO] Processing video: V_489.mp4...
#   -> Extracted 120 frames.
# [INFO] Processing video: V_491.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_492.mp4...
#   -> Extracted 153 frames.
# [INFO] Processing video: V_493.mp4...
#   -> Extracted 108 frames.
# [INFO] Processing video: V_494.mp4...
#   -> Extracted 132 frames.
# [INFO] Processing video: V_495.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_496.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_497.mp4...
#   -> Extracted 144 frames.
# [INFO] Processing video: V_498.mp4...
#   -> Extracted 138 frames.
# [INFO] Processing video: V_499.mp4...
#   -> Extracted 129 frames.
# [INFO] Processing video: V_500.mp4...
#   -> Extracted 147 frames.
# [INFO] Processing video: NV_401.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_402.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_403.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_404.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_405.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_406.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_407.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_408.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_409.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_410.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_411.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_412.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_413.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_414.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_415.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_416.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_417.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_418.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_419.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_421.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_422.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_423.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_424.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_425.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_426.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_427.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_428.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_429.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_430.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_431.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_432.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_433.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_434.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_435.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_436.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_437.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_438.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_439.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_441.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_442.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_443.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_444.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_445.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_446.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_447.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_448.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_449.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_450.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_451.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_452.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_453.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_454.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_455.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_456.mp4...
#   -> Extracted 145 frames.
# [INFO] Processing video: NV_457.mp4...
#   -> Extracted 145 frames.
# [INFO] Processing video: NV_458.mp4...
#   -> Extracted 145 frames.
# [INFO] Processing video: NV_459.mp4...
#   -> Extracted 145 frames.
# [INFO] Processing video: NV_461.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_462.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_463.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_464.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_465.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_466.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_467.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_468.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_469.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_470.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_471.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_472.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_473.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_474.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_475.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_476.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_477.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_478.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_479.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_481.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_482.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_483.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_484.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_485.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_486.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_487.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_488.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_489.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_490.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_491.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_492.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_493.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_494.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_495.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_496.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_497.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_498.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_499.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_500.mp4...
#   -> Extracted 115 frames.
# [INFO] Processing video: NV_420.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_440.mp4...
#   -> Extracted 55 frames.
# [INFO] Processing video: NV_460.mp4...
#   -> Extracted 145 frames.
# [INFO] Processing video: NV_480.mp4...
#   -> Extracted 115 frames.
#
# [SUCCESS] All videos have been processed and frames have been extracted.

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Image
from transformers import (
    AutoImageProcessor,
    AutoModelForImageClassification,
    TrainingArguments,
    Trainer,
    DefaultDataCollator
)
import evaluate


FINETUNED_MODEL_PATH = "/media/rajendraprasath-m/New Volume/Projects/Final Year Project/vit_final_model"
BASE_MODEL_NAME = "google/vit-base-patch16-224-in21k"


# --- Configuration ---
# --- START OF CRITICAL CHANGE: Using a standard Google ViT model ---
MODEL_NAME = "google/vit-base-patch16-224-in21k"
# --- END OF CRITICAL CHANGE ---

# Path to your dataset (This is correct)
DATASET_PATH = "/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Extracted_Frames"

# The name for your NEW model
FINETUNED_MODEL_PATH = os.path.expanduser("/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Model")

# --- GPU Setup ---
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"[INFO] Using device: {device}")
# Out:
# [INFO] Using device: cuda:0

# %%
dataset = load_dataset("imagefolder", data_dir=DATASET_PATH)

labels = dataset["train"].features["label"].names
label2id = {label: i for i, label in enumerate(labels)}
id2label = {i: label for i, label in label2id.items()}

image_processor = AutoImageProcessor.from_pretrained(MODEL_NAME)


def transform(example_batch):
    images = [img.convert("RGB") for img in example_batch["image"]]
    inputs = image_processor(images, return_tensors="pt")
    inputs["labels"] = example_batch["label"]
    return inputs



# ✅ IMPORTANT: no assignment here
dataset.set_transform(transform)

data_collator = DefaultDataCollator()

dataset["train"] = dataset["train"].shuffle(seed=42).select(range(2000))
dataset["test"]  = dataset["test"].shuffle(seed=42).select(range(500))
# Out:
# Downloading data: 100%|██████████| 54351/54351 [00:03<00:00, 17077.51files/s]
# Downloading data: 100%|██████████| 21937/21937 [00:01<00:00, 16851.73files/s]
# Generating train split: 54351 examples [00:02, 20769.84 examples/s]
# Generating test split: 21937 examples [00:01, 20264.19 examples/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.

# %%
# --- Define Metrics Function ---
accuracy_metric = evaluate.load("accuracy")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# --- Load the Standard Google ViT Model for Fine-Tuning ---
model = AutoModelForImageClassification.from_pretrained(
    MODEL_NAME,
    num_labels=len(labels),
    label2id=label2id,
    id2label=id2label,
)
model.to(device)

# --- Define Training Arguments ---
training_args = TrainingArguments(
    output_dir=FINETUNED_MODEL_PATH,
    eval_strategy="epoch",
    save_strategy="epoch",

    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,

    num_train_epochs=10,
    learning_rate=1e-5,

    remove_unused_columns=False,
    fp16=True,                 # 🚀 HUGE SPEEDUP
    report_to="none",
)


# --- Initialize the Trainer (FIXED) ---
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
trainer.save_model(FINETUNED_MODEL_PATH)
print(f"\n[SUCCESS] GPU Training complete. Model saved to: {FINETUNED_MODEL_PATH}")

print("[INFO] Trainer is set up and ready.")
# Out:
# Downloading builder script: 4.20kB [00:00, 161kB/s]
# Loading weights: 100%|██████████| 198/198 [00:00<00:00, 633.59it/s, Materializing param=vit.layernorm.weight]
# ViTForImageClassification LOAD REPORT from: google/vit-base-patch16-224-in21k
# Key                 | Status     |
# --------------------+------------+-
# pooler.dense.bias   | UNEXPECTED |
# pooler.dense.weight | UNEXPECTED |
# classifier.weight   | MISSING    |
# classifier.bias     | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [INFO] Trainer is set up and ready.

# %%
for param in model.vit.parameters():
    param.requires_grad = False

for param in model.vit.encoder.layer[-1].parameters():
    param.requires_grad = True

# %%
print("[INFO] Starting GPU fine-tuning...")
trainer.train()
# Out:
# [INFO] Starting GPU fine-tuning...
#     <div>
#
#       <progress value='630' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [630/630 05:05, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.456881</td>
#       <td>0.816000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.425943</td>
#       <td>0.832000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.400782</td>
#       <td>0.836000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.381054</td>
#       <td>0.838000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.365963</td>
#       <td>0.838000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.355486</td>
#       <td>0.842000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.348466</td>
#       <td>0.842000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.179144</td>
#       <td>0.343824</td>
#       <td>0.844000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.179144</td>
#       <td>0.341501</td>
#       <td>0.844000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.179144</td>
#       <td>0.340715</td>
#       <td>0.844000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.34s/it]
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]
# TrainOutput(global_step=630, training_loss=0.16366966187007845, metrics={'train_runtime': 305.5882, 'train_samples_per_second': 65.448, 'train_steps_per_second': 2.062, 'total_flos': 1.54983979229184e+18, 'train_loss': 0.16366966187007845, 'epoch': 10.0})

# %%
# trainer.save_model(FINETUNED_MODEL_PATH)
# print(f"\n[SUCCESS] GPU Training complete. Model saved to: {FINETUNED_MODEL_PATH}")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# [SUCCESS] GPU Training complete. Model saved to: /media/rajendraprasath-m/New Volume/Projects/Final Year Project/Model

# %%
trainer.save_model("vit_final_model")
image_processor.save_pretrained("vit_final_model")
# Out:
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# ['vit_final_model/preprocessor_config.json']

# %%
from transformers import AutoModelForImageClassification, AutoImageProcessor

MODEL_PATH = "vit_final_model"

processor = AutoImageProcessor.from_pretrained(MODEL_PATH)
model = AutoModelForImageClassification.from_pretrained(MODEL_PATH)

print(model.config.id2label)
# Out:
# Loading weights: 100%|██████████| 200/200 [00:00<00:00, 536.45it/s, Materializing param=vit.layernorm.weight]
# {0: 'NonViolence', 1: 'Violence'}

# %%
import cv2
import torch
import numpy as np
from transformers import AutoImageProcessor, AutoModelForImageClassification
from PIL import Image

# ---------------- CONFIG ----------------
MODEL_PATH = "/media/rajendraprasath-m/New Volume/Projects/Final Year Project/vit_final_model"
VIDEO_PATH = "/media/rajendraprasath-m/New Volume/Projects/Final Year Project/Data/Video/Violence/V_206.mp4"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
FRAME_INTERVAL = 30   # ~1 frame per second (for 30 FPS video)
# ---------------------------------------

# Load model & processor
processor = AutoImageProcessor.from_pretrained(MODEL_PATH)
model = AutoModelForImageClassification.from_pretrained(MODEL_PATH)
model.to(DEVICE)
model.eval()

# Label mapping
id2label = model.config.id2label
label2id = model.config.label2id
print("Labels:", id2label)

# Storage for probabilities
prob_storage = {label: [] for label in id2label.values()}

# Read video
cap = cv2.VideoCapture(VIDEO_PATH)
frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    if frame_count % FRAME_INTERVAL == 0:
        # BGR → RGB → PIL
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(frame_rgb)

        # Preprocess
        inputs = processor(image, return_tensors="pt").to(DEVICE)

        with torch.no_grad():
            outputs = model(**inputs)
            probs = torch.softmax(outputs.logits, dim=1)[0].cpu().numpy()

        # Store probabilities using label names
        for idx, prob in enumerate(probs):
            label = id2label[idx]
            prob_storage[label].append(prob)

    frame_count += 1

cap.release()

# ---------------- RESULTS ----------------
avg_probs = {
    label: np.mean(values) * 100
    for label, values in prob_storage.items()
}

final_label = max(avg_probs, key=avg_probs.get)

print("\n🎥 VIDEO ANALYSIS RESULT")
for label, prob in avg_probs.items():
    print(f"{label:15}: {prob:.2f}%")

print(f"\n✅ FINAL PREDICTION: {final_label.upper()}")
# Out:
# Loading weights: 100%|██████████| 200/200 [00:00<00:00, 669.21it/s, Materializing param=vit.layernorm.weight]
# Labels: {0: 'NonViolence', 1: 'Violence'}
#
# 🎥 VIDEO ANALYSIS RESULT
# NonViolence    : 9.72%
# Violence       : 90.28%
#
# ✅ FINAL PREDICTION: VIOLENCE
